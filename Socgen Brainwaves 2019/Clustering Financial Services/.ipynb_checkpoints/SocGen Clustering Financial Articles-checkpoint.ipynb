# %%
# %matplotlib notebook
# %matplotlib inline
import pandas as pd
import numpy as np
import re as re
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
import random, sys, os
import warnings
warnings.filterwarnings('ignore')
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import KFold
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import (RandomForestClassifier, AdaBoostClassifier,
                              GradientBoostingClassifier, ExtraTreesClassifier)

# %%
df = pd.read_csv('dataset/news.csv')
print(df.info())
df.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
# id          3000 non-null object
# headline    3000 non-null object
# text        3000 non-null object
# dtypes: object(3)
# memory usage: 70.4+ KB
# None
#       id                                           headline  \
# 0  uid-1                          Market Advances 5.12 More
# 1  uid-2  District Boosts Request For Anti-Terrorism Aid...
# 2  uid-3              Election? Here's How You Do It, Mate.
# 3  uid-4                              The Biggest Boom Ever
# 4  uid-5                         Economic Aide Sees Uptrend
#
#                                                 text
# 0  NEW YORK (AP) - A prime rate reduction by New ...
# 1  Mayor Anthony A. Williams petitioned the White...
# 2  From our downunder perspective here in Austral...
# 3  We are about to rewrite history. Unless a rece...
# 4  Sedate and scholarly Dr. Arthur Burns, the ex-...

# %%
print('ï¿½ï¿½ï¿½')
print('ï¿½Ûªs')
df['cluster'] = 0
df['text_len'] = df['text'].apply(lambda x: len(x))
df['text_array'] = df['text'].apply(lambda x: x.split(' '))
len(df['text_array'])
df['text_array_1'] = df['text_array'].apply(lambda x: x[0])
df.loc[df['text_array_1'] == 'Author:','cluster'] = 1
df[df['text_array_1'] == 'Author:']
df.head(3)
# Out:
# ï¿½ï¿½ï¿½
# ï¿½Ûªs
#       id                                           headline  \
# 0  uid-1                          Market Advances 5.12 More
# 1  uid-2  District Boosts Request For Anti-Terrorism Aid...
# 2  uid-3              Election? Here's How You Do It, Mate.
#
#                                                 text  cluster  text_len  \
# 0  NEW YORK (AP) - A prime rate reduction by New ...        0       779
# 1  Mayor Anthony A. Williams petitioned the White...        0      1218
# 2  From our downunder perspective here in Austral...        0      1843
#
#                                           text_array text_array_1
# 0  [NEW, YORK, (AP), -, A, prime, rate, reduction...          NEW
# 1  [Mayor, Anthony, A., Williams, petitioned, the...        Mayor
# 2  [From, our, downunder, perspective, here, in, ...         From

# %%
# LDA TOPIC MODELLING
import pickle
import gensim
from sklearn.feature_extraction.text import CountVectorizer

# Use CountVectorizor to find three letter tokens, remove stop_words, 
# remove tokens that don't appear in at least 20 documents,
# remove tokens that appear in more than 20% of the documents
vect = CountVectorizer(min_df=20, max_df=0.2, stop_words='english', 
                       token_pattern='(?u)\\b\\w\\w\\w+\\b')
# Fit and transform
X = vect.fit_transform(df['text'])

# Convert sparse matrix to gensim corpus.
corpus = gensim.matutils.Sparse2Corpus(X, documents_columns=False)

# Mapping from word IDs to words (To be used in LdaModel's id2word parameter)
id_map = dict((v, k) for k, v in vect.vocabulary_.items())

# %%
topic = 3
ldamodel = gensim.models.ldamodel.LdaModel(corpus=corpus,passes=25,random_state=34,num_topics=topic,id2word=id_map)

# %%
def lda_topics():
    # Your Code Here
    ans = [(i,ldamodel.print_topic(topicno=i)) for i in range(topic) ]
    return ans
lda_topics()
# Out:
# [(0,
#   '0.008*"tax" + 0.007*"budget" + 0.006*"state" + 0.006*"house" + 0.005*"people" + 0.005*"percent" + 0.005*"administration" + 0.005*"unemployment" + 0.005*"spending" + 0.004*"washington"'),
#  (1,
#   '0.011*"stocks" + 0.010*"rose" + 0.010*"percent" + 0.010*"index" + 0.008*"quarter" + 0.008*"dow" + 0.008*"points" + 0.007*"trading" + 0.007*"fell" + 0.007*"month"'),
#  (2,
#   '0.011*"billion" + 0.010*"fed" + 0.009*"bank" + 0.009*"company" + 0.008*"financial" + 0.007*"markets" + 0.007*"banks" + 0.006*"companies" + 0.006*"money" + 0.006*"investors"')]

# %%
a = [df['text'][5]]
def topic_distribution(row):    
    X = vect.transform(row)
    corp = gensim.matutils.Sparse2Corpus(X, documents_columns=False)
    return list(ldamodel.get_document_topics(corp))[0]
topic_distribution(a)
# Out:
# [(0, 0.795611), (1, 0.06768485), (2, 0.13670412)]

# %%
r = np.zeros((3000,topic))
for i,row in enumerate(df['text']):
    topic_proba = topic_distribution([row])
    for topic in topic_proba:
        index = int(topic[0])
        val = float(topic[1])
        r[i][index] = val

# %%
np.savetxt('submission_lda1.txt',X=r)

# %%
def check(row):
    return np.argmax(row)
du = pd.read_csv('submission_lda1.txt',sep=' ',header=None)
du['cluster'] = du.apply(check,axis=1)
du.head()
Submission = pd.DataFrame({ 'id':df['id'] ,
                            'cluster': du['cluster'] })
Submission.to_csv("submission_lda1.csv", index=False)

# %%
# KMEANS TOPIC MODELLING

# %%
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer
porter = PorterStemmer()
lancaster=LancasterStemmer()
print(porter.stem(df['text'][0]))
print(lancaster.stem(df['text'][0]))
# Out:
# new york (ap) - a prime rate reduction by new york's first national city bank helped the stock market close out the busiest week in its history with a modest advance friday.</br></br>the dow jones average of 30 industrial stocks gained 5.12 to 929.63, finishing the week withanetrise of 18.50 points.</br></br>big board volume, at 25.94 million shares, fell a good deal short of matching thursday's all-time high of 38.45 million.</br></br>but the day�۪s figure was more than enough to push the total for the week to a record 159.69 million shares. the previous peak had been 145.68 million in the last week of january 1975.</br></br>the dow has advanced in all but two of the first 11 sessions of the new year. as of friday�۪s close it had gained 77.22 points since new year�۪s.
# new york (ap) - a prime rate reduction by new york's first national city bank helped the stock market close out the busiest week in its history with a modest advance friday.</br></br>the dow jones average of 30 industrial stocks gained 5.12 to 929.63, finishing the week withanetrise of 18.50 points.</br></br>big board volume, at 25.94 million shares, fell a good deal short of matching thursday's all-time high of 38.45 million.</br></br>but the day�۪s figure was more than enough to push the total for the week to a record 159.69 million shares. the previous peak had been 145.68 million in the last week of january 1975.</br></br>the dow has advanced in all but two of the first 11 sessions of the new year. as of friday�۪s close it had gained 77.22 points since new year�۪s.

# %%
from nltk.tokenize import sent_tokenize, word_tokenize
def stemSentence(sentence):
    token_words=word_tokenize(sentence)
    token_words
    stem_sentence=[]
    for word in token_words:
        stem_sentence.append(porter.stem(word))
        stem_sentence.append(" ")
    return "".join(stem_sentence)
stemSentence(df['text'][0])
# Out:
# "new york ( AP ) - A prime rate reduct by new york 's first nation citi bank help the stock market close out the busiest week in it histori with a modest advanc friday. < /br > < /br > the dow jone averag of 30 industri stock gain 5.12 to 929.63 , finish the week withanetris of 18.50 points. < /br > < /br > big board volum , at 25.94 million share , fell a good deal short of match thursday 's all-tim high of 38.45 million. < /br > < /br > but the day�۪ figur wa more than enough to push the total for the week to a record 159.69 million share . the previou peak had been 145.68 million in the last week of januari 1975. < /br > < /br > the dow ha advanc in all but two of the first 11 session of the new year . As of friday�۪ close it had gain 77.22 point sinc new year�۪ . "

# %%
import nltk
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
# from nltk.stem import WordNetLemmatizer
# wordnet_lemmatizer = WordNetLemmatizer()
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    punctuations="?:!.,;'�۪"
    for token in tokens:
        if token in punctuations:
            tokens.remove(token)
        if re.search('[a-zA-Z0-9]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
#     stems = [wordnet_lemmatizer.lemmatize(t) for t in filtered_tokens]
    st = ' '.join(stems)
    t = st.replace("/br","")
    u = t.replace("�","")
    u = ' '.join(u.split())
    return u
tokenize_and_stem(df['text'][0])
# Out:
# "new york ap a prime rate reduct by new york 's first nation citi bank help the stock market close out the busiest week in it histori with a modest advanc friday. the dow jone averag of 30 industri stock gain 5.12 to 929.63 the week withanetris of 18.50 points. big board volum 25.94 million share a good deal short of match thursday 's all-tim high of 38.45 million. but the day۪ figur was more than enough to push the total for the week to a record 159.69 million share previous peak had been 145.68 million in the last week of januari 1975. the dow has advanc in all but two of the first 11 session of the new year of friday۪ close it had gain 77.22 point sinc new year۪"

# %%
# df['text_formatted'] = df['text'].apply(tokenize_and_stem)
# df['text_formatted']
# Out:
# 0       new york ap a prime rate reduct by new york 's...
# 1       mayor anthoni a. william petit the white hous ...
# 2       from our downund perspect here in australia un...
# 3       we are about to rewrit histori a recess begin ...
# 4       sedat and scholar dr. arthur burn ex-columbia ...
# 5       the statist on the enorm cost of employe drug ...
# 6       global market end the third quarter much the s...
# 7       consum borrow surg in juli reflect heavi credi...
# 8       washington the unexpect declin in septemb 's u...
# 9       -immr ab travel master of ceremoni and salcb m...
# 10      the price of america onlin inc. 's stock surg ...
# 11      david m. kennedi next secretari of the u.s. tr...
# 12      new york 12presi-de'nt bush the polit defens a...
# 13      washington general motor corp. chairman roger ...
# 14      one of the big problem that most of us have in...
# 15      busi product in the second quarter deterior at...
# 16      is washington just a nice place to visit shoul...
# 17      presid carter call on the nation۪ larg corpor ...
# 18      earlier this month an ad appear in this newspa...
# 19      sale of new home tumbl 5.8 percent in april wh...
# 20      on wall street the year of the calland for inc...
# 21      the number of agricultur bank head toward fail...
# 22      the wall street journal recent report that fan...
# 23      the bull market in american stock has given th...
# 24      today bush administr and congress will start s...
# 25      white sulphur spring 17the chairman of the sen...
# 26      new-hom sale fell for the fourth-straight mont...
# 27      by ani measur was a brutal year for the local ...
# 28      denver consolid oil gas inc. said the respons ...
# 29      new york crude futur were near flat as trader ...
#                               ...
# 2970    for the past 41 years-or ever sinc the two len...
# 2971    volkswagen said it will accept that u.s. court...
# 2972    boston with the big dig more than halfway done...
# 2973    the dollar is expect to advanc against the yen...
# 2974    richard baker big investor in shop center and ...
# 2975    washington area compani are come out of the hu...
# 2976    an industry-support research group yesterday s...
# 2977    is more of a good thing realli better by all a...
# 2978    u.s. stock surg as investor focus on hope for ...
# 2979    if the world has chang your portfolio should i...
# 2980    wait for congress to pass the much-need econom...
# 2981    dow jone newswir new york small stock did n't ...
# 2982    washington chairman lloyd bentsen of the senat...
# 2983    it is now just about 7 year sinc the great mon...
# 2984    secretari of labor jame p mitchel took issu ye...
# 2985    is your retir secur para for some peopl who th...
# 2986    3.5 percent next year and social secur tax wil...
# 2987    annapoli 8maryland gov donald schaefer decid l...
# 2988    consum spend rebound 0.7 percent in novemb fro...
# 2989    polit discours in modern america usual proceed...
# 2990    republican legisl accus the democrat governor ...
# 2991    most peopl think factori should run with machi...
# 2992    consum confid fell slight in februari from jan...
# 2993    economi mild inflat read should n't portend da...
# 2994    it sometim seem as if almost everyth we buy co...
# 2995    washington the govern 's latest employ report ...
# 2996    richard parson say the 13 billion penalti extr...
# 2997    drug maker merck is hope it can reenter a lucr...
# 2998    tokyo japan report an unexpect trade deficit i...
# 2999    what next from the folk who gave the world the...
# Name: text_formatted, Length: 3000, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#define vectorizer parameters
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=200000,
                                 min_df=0.2, stop_words='english',
                                 use_idf=True, tokenizer=tokenize_and_stem, ngram_range=(1,3))

# %time tfidf_matrix = tfidf_vectorizer.fit_transform(df['text']).todense() #fit the vectorizer to synopses

print(tfidf_matrix.shape)
terms = tfidf_vectorizer.get_feature_names()
# Out:
# CPU times: user 15.7 s, sys: 11.9 ms, total: 15.7 s
# Wall time: 15.8 s
# (3000, 963)

# %%
# %matplotlib
from sklearn.decomposition import PCA
# from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt

# pipeline = Pipeline([
#     ('vect', CountVectorizer()),
#     ('tfidf', TfidfTransformer()),
# ])        
# X = pipeline.fit_transform(newsgroups_train.data).todense()

pca = PCA(n_components=2).fit(x)
data2D = pca.transform(x)
# transfromed_data2D = km.fit_transform(data2D)
num_clusters = 3

km = KMeans(n_clusters=num_clusters,n_jobs=-1,algorithm="auto",init='k-means++',max_iter=120,n_init=2)

# %time km.fit(data2D)

clusters = km.labels_.tolist()

plt.scatter(data2D[:,0], data2D[:,1], c=km.labels_)
plt.show()

# clust = pd.Series(clusters)
# Out:
# Using matplotlib backend: nbAgg
# CPU times: user 48.1 ms, sys: 0 ns, total: 48.1 ms
# Wall time: 12.1 ms
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=4).fit(x)
data = pca.transform(x)
transfromed_data = km.fit_transform(data)
num_clusters = 3

km = KMeans(n_clusters=num_clusters,n_jobs=-1,algorithm="auto",init='k-means++',max_iter=120,n_init=2)
# %time km.fit(data2D)
clusters = km.labels_.tolist()
clust = pd.Series(clusters)

# %%
np.savetxt('submission_kmeans1.txt',X=transfromed_data)
df['cluster'] = clust
Submission = pd.DataFrame({ 'id':df['id'] ,
                            'cluster': df['cluster'] })
Submission.to_csv("submission_kmeans1.csv", index=False)

# %%
df.head()
# Out:
#       id                                           headline  \
# 0  uid-1                          Market Advances 5.12 More
# 1  uid-2  District Boosts Request For Anti-Terrorism Aid...
# 2  uid-3              Election? Here's How You Do It, Mate.
# 3  uid-4                              The Biggest Boom Ever
# 4  uid-5                         Economic Aide Sees Uptrend
#
#                                                 text  cluster  text_len  \
# 0  NEW YORK (AP) - A prime rate reduction by New ...        0       779
# 1  Mayor Anthony A. Williams petitioned the White...        1      1218
# 2  From our downunder perspective here in Austral...        0      1843
# 3  We are about to rewrite history. Unless a rece...        0      3825
# 4  Sedate and scholarly Dr. Arthur Burns, the ex-...        0      2195
#
#                                           text_array text_array_1  \
# 0  [NEW, YORK, (AP), -, A, prime, rate, reduction...          NEW
# 1  [Mayor, Anthony, A., Williams, petitioned, the...        Mayor
# 2  [From, our, downunder, perspective, here, in, ...         From
# 3  [We, are, about, to, rewrite, history., Unless...           We
# 4  [Sedate, and, scholarly, Dr., Arthur, Burns,, ...       Sedate
#
#                                       text_formatted
# 0  new york ap a prime rate reduct by new york 's...
# 1  mayor anthoni a. william petit the white hous ...
# 2  from our downund perspect here in australia un...
# 3  we are about to rewrit histori a recess begin ...
# 4  sedat and scholar dr. arthur burn ex-columbia ...

# %%
# Submission = pd.DataFrame({ 'id':df['id'] ,
#                             'cluster': du['cluster'] })
# Submission.to_csv("Submission_1.csv", index=False)
